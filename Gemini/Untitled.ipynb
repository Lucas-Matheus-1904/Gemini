# %%
pip install google-generativeai
# Out:
# Collecting google-generativeaiNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for google-generativeai from https://files.pythonhosted.org/packages/ae/24/c282649e1b07cc2b8db6ce5d3293b526487fa011d7ed09fd4cac3a3f29af/google_generativeai-0.4.0-py3-none-any.whl.metadata
#   Downloading google_generativeai-0.4.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting google-ai-generativelanguage==0.4.0 (from google-generativeai)
#   Obtaining dependency information for google-ai-generativelanguage==0.4.0 from https://files.pythonhosted.org/packages/40/c2/d28988d3cba74e712f47a498e2b3e3b58ac215106019bf5d8c20f8ab9822/google_ai_generativelanguage-0.4.0-py3-none-any.whl.metadata
#   Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\usuário\anaconda3\lib\site-packages (from google-generativeai) (2.27.0)
# Collecting google-api-core (from google-generativeai)
#   Obtaining dependency information for google-api-core from https://files.pythonhosted.org/packages/0f/87/373ab788a4682adc1a6900e54d54c750b7bd4be456d75b8bf64eccc23ef9/google_api_core-2.17.1-py3-none-any.whl.metadata
#   Downloading google_api_core-2.17.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: protobuf in c:\users\usuário\anaconda3\lib\site-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in c:\users\usuário\anaconda3\lib\site-packages (from google-generativeai) (1.10.8)
# Requirement already satisfied: tqdm in c:\users\usuário\anaconda3\lib\site-packages (from google-generativeai) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\usuário\anaconda3\lib\site-packages (from google-generativeai) (4.9.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.4.0->google-generativeai)
#   Obtaining dependency information for proto-plus<2.0.0dev,>=1.22.3 from https://files.pythonhosted.org/packages/ad/41/7361075f3a31dcd05a6a38cfd807a6eecbfb6dbfe420d922cd400fc03ac1/proto_plus-1.23.0-py3-none-any.whl.metadata
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\usuário\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usuário\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usuário\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core->google-generativeai)
#   Obtaining dependency information for googleapis-common-protos<2.0.dev0,>=1.56.2 from https://files.pythonhosted.org/packages/f0/43/c9d8f75ddf08e2a0a27db243c13a700c3cc7ec615b545b697cf6f715ad92/googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\usuário\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: colorama in c:\users\usuário\anaconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\usuário\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.60.0)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core->google-generativeai)
#   Obtaining dependency information for grpcio-status<2.0.dev0,>=1.33.2 from https://files.pythonhosted.org/packages/09/49/52e46bcea1c7b07b87982e4f7ea8657c8679f1591c4eafc75f84549939ae/grpcio_status-1.62.1-py3-none-any.whl.metadata
#   Downloading grpcio_status-1.62.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\usuário\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuário\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuário\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuário\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuário\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# Collecting protobuf (from google-generativeai)
#   Obtaining dependency information for protobuf from https://files.pythonhosted.org/packages/ad/6e/1bed3b7c904cc178cb8ee8dbaf72934964452b3de95b7a63412591edb93c/protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core->google-generativeai)
#   Obtaining dependency information for grpcio<2.0dev,>=1.33.2 from https://files.pythonhosted.org/packages/78/a9/eaa378e6fe421c2f61bdd4b92439b2b8bb320526f2b0e08fcf4e21c2f855/grpcio-1.62.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading grpcio-1.62.1-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Downloading google_generativeai-0.4.0-py3-none-any.whl (137 kB)
#    ---------------------------------------- 0.0/137.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/137.4 kB ? eta -:--:--
#    ----------------------- --------------- 81.9/137.4 kB 919.0 kB/s eta 0:00:01
#    ---------------------------------------- 137.4/137.4 kB 1.0 MB/s eta 0:00:00
# Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl (598 kB)
#    ---------------------------------------- 0.0/598.7 kB ? eta -:--:--
#    -------- ------------------------------- 122.9/598.7 kB 7.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 256.0/598.7 kB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 491.5/598.7 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  593.9/598.7 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 598.7/598.7 kB 2.9 MB/s eta 0:00:00
# Downloading google_api_core-2.17.1-py3-none-any.whl (137 kB)
#    ---------------------------------------- 0.0/137.0 kB ? eta -:--:--
#    -------------------------------------- - 133.1/137.0 kB 7.7 MB/s eta 0:00:01
#    -------------------------------------- - 133.1/137.0 kB 7.7 MB/s eta 0:00:01
#    -------------------------------------- - 133.1/137.0 kB 7.7 MB/s eta 0:00:01
#    -------------------------------------- 137.0/137.0 kB 812.8 kB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ---------------------------------------- 0.0/228.7 kB ? eta -:--:--
#    --------------------------------------  225.3/228.7 kB 14.3 MB/s eta 0:00:01
#    ---------------------------------------- 228.7/228.7 kB 2.8 MB/s eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    --------------------------------- ------ 41.0/48.8 kB ? eta -:--:--
#    --------------------------------- ------ 41.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB 308.3 kB/s eta 0:00:00
# Downloading grpcio_status-1.62.1-py3-none-any.whl (14 kB)
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 13.0 MB/s eta 0:00:00
# Downloading grpcio-1.62.1-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.6/3.8 MB 17.3 MB/s eta 0:00:01
#    -------- ------------------------------- 0.8/3.8 MB 8.5 MB/s eta 0:00:01
#    -------------- ------------------------- 1.4/3.8 MB 11.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.9/3.8 MB 9.9 MB/s eta 0:00:01
#    ------------------------- -------------- 2.4/3.8 MB 10.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 11.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: protobuf, grpcio, proto-plus, googleapis-common-protos, grpcio-status, google-api-core, google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.60.0
#     Uninstalling grpcio-1.60.0:
#       Successfully uninstalled grpcio-1.60.0
# Successfully installed google-ai-generativelanguage-0.4.0 google-api-core-2.17.1 google-generativeai-0.4.0 googleapis-common-protos-1.62.0 grpcio-1.62.1 grpcio-status-1.62.1 proto-plus-1.23.0 protobuf-4.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.9 requires protobuf<4,>=3.11, but you have protobuf 4.25.3 which is incompatible.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.25.3 which is incompatible.

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAIDN4mnonog2k6Lt1hfgGox3ePpI2wP6o")

for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)

model = genai.GenerativeModel('gemini-pro')

chat = model.start_chat(history=[])

bem_vindo = "# JARVIS #"
print(len(bem_vindo) * "#")
print(bem_vindo)
print(len(bem_vindo) * "#")
print("###   Digite 'sair' para encerrar    ###")
print("")

while True:
    texto = input("Escreva sua mensagem: ")

    if texto == "sair":
        break

    response = chat.send_message(texto)
    print("Jarvis:", response.text, "\n")

print("Encerrando Chat")
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision
# ##########
# # JARVIS #
# ##########
# ###   Digite 'sair' para encerrar    ###
#
# Escreva sua mensagem: me fale sobre LuLa
# Jarvis: **LuLaRoe**
#
# **O que é LuLaRoe?**
#
# LuLaRoe é uma empresa de marketing multinível (MLM) que vende roupas para mulheres, homens e crianças. A empresa é conhecida por seus vestidos maxi estampados, leggings e túnicas.
#
# **História**
#
#
# **Legado:**
#
# Lula é amplamente considerado um dos políticos mais importantes e influentes da história brasileira. Ele é creditado por liderar o Brasil em um período de prosperidade econômica e progresso social. No entanto, seu legado também é prejudicado por alegações de corrupção.
#
# Escreva sua mensagem: agora sobre Bolsonaro, ex presidente do Brasil e aponte suas maiores conquistas
# Jarvis: **Jair Bolsonaro**
#
# **Nascimento:** 21 de março de 1955, em Glicério, São Paulo, Brasil
#
# **Apelido:** Capitão Bolsonaro
#
# **Partido político:** Partido Liberal (PL)
#
# **Cargos ocupados:**
#
# * Presidente do Brasil (2019-2022)
# * Deputado federal pelo Rio de Janeiro (1991-2018)
#
# **Biografia:**
#
# Jair Bolsonaro é um político brasileiro que serviu como Presidente do Brasil de 2019 a 2022. Ele é um ex-capitão do Exército e é conhecido por suas opiniões polêmicas e de direita.
#
# **Presidência (2019-2022):**
#
# Bolsonaro foi eleito presidente do Brasil em 2018. Durante sua presidência, implementou uma série de políticas conservadoras, incluindo:
#
# * Redução do tamanho do governo e desregulamentação da economia
# * Aumento dos gastos militares
# * Afrouxamento das leis sobre armas
# * Restrições aos direitos LGBTQ+
#
# **Maiores Conquistas:**
#
# Apesar de sua presidência controversa, Bolsonaro conquistou algumas conquistas notáveis, incluindo:
#
# * **Redução da criminalidade:** As taxas de criminalidade diminuíram durante a presidência de Bolsonaro, embora não esteja claro se isso se deve às suas políticas ou a outros fatores.
# * **Crescimento econômico:** A economia brasileira cresceu durante a presidência de Bolsonaro, embora tenha sido afetada pela pandemia de COVID-19.
# * **Redução da dívida pública:** Bolsonaro reduziu a dívida pública do Brasil como porcentagem do PIB.
# * **Aprovação de reformas previdenciárias:** Bolsonaro aprovou uma reforma da previdência que aumentou a idade de aposentadoria e reduziu os benefícios.
#
# **Legado:**
#
# O legado de Bolsonaro é misto. Ele é creditado por reduzir as taxas de criminalidade e melhorar a economia. No entanto, ele também é criticado por sua retórica divisiva, ataques à democracia e gestão da pandemia de COVID-19.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 21
#      18 print("")
#      20 while True:
# ---> 21     texto = input("Escreva sua mensagem: ")
#      23     if texto == "sair":
#      24         break
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
